# %% [markdown]
# # SynFlow Data Prep
#
# Prepare raw sentence corpora in SynFlow format.

# %%
# %load_ext autoreload
# %autoreload 2

import sys
from pathlib import Path

repo_root = str(Path("..").resolve())
if repo_root not in sys.path:
    sys.path.insert(0, repo_root)

from SynFlow.Data import hanlp_stanza_parse_folder, stanza_parse_folder

# %% [markdown]
# ## Stanza Dependency Parse
#
# Use this section to dependency-parse raw sentence files into SynFlow's seven-field parsed-token format.

# %%
stanza_input_root = Path("/home/volt/bach/pilot_data/float_gen")
stanza_output_root = Path("/home/volt/bach/pilot_data/float_gen_parsed")

# Choose the Stanza language and model/processors explicitly.
stanza_language = "en"
stanza_model = "ewt"
stanza_processors = "tokenize,mwt,pos,lemma,depparse"
# stanza_processor_models = {
#     "tokenize": "gsd",
#     "mwt": "gsd",
#     "pos": "hdt",
#     "lemma": "hdt",
#     "depparse": "hdt",
# }

# %%
stanza_parse_folder(
    stanza_input_root,
    stanza_output_root,
    language=stanza_language,
    model=stanza_model,
    processors=stanza_processors,
    # processor_models=stanza_processor_models,
    gpu="2,3",
    workers_per_gpu=2,
    batch_size=128,
    overwrite=False,
)

# %% [markdown]
# ## HanLP + Stanza SRL Parse
#
# Use this section to run HanLP semantic role labelling and Stanza component lemmatisation into SynFlow's seven-field format.

# %%
import hanlp

srl_input_root = Path("/home/volt/bach/pilot_data/float_gen")
srl_output_root = Path("/home/volt/bach/pilot_data/float_gen_srl")

# GPUs and parallel processing.
srl_gpu = "2,3"
srl_workers_per_gpu = 1

# HanLP sentence batch size.
hanlp_batch_size = 32

# Choose the HanLP SRL model and Stanza lemmatisation model explicitly.
hanlp_srl_model_name = (
    hanlp.pretrained.mtl.EN_TOK_LEM_POS_NER_SRL_UDEP_SDP_CON_MODERNBERT_LARGE
)
stanza_srl_language = "en"
stanza_srl_package = {"tokenize": "ewt", "pos": "ewt", "lemma": "ewt"}

# %%
# If this is the first time using this Stanza language package, run once:
# import stanza
# stanza.download(stanza_srl_language)

hanlp_stanza_parse_folder(
    srl_input_root,
    srl_output_root,
    hanlp_model_name=hanlp_srl_model_name,
    language=stanza_srl_language,
    stanza_package=stanza_srl_package,
    gpu=srl_gpu,
    workers_per_gpu=srl_workers_per_gpu,
    hanlp_batch_size=hanlp_batch_size,
    overwrite=False,
)
# Out:
# Input root: /home/volt/bach/pilot_data/float_gen
# Output root: /home/volt/bach/pilot_data/float_gen_srl
# Files: 1
# HanLP model: https://file.hankcs.com/hanlp/mtl/en_tok_lem_pos_ner_srl_udep_sdp_con_modernbert_large_prepend_false_20250107_181612.zip; Stanza language: en; Stanza package: {'tokenize': 'ewt', 'pos': 'ewt', 'lemma': 'ewt'}; Stanza processors: tokenize,pos,lemma
# GPUs: cuda:2, cuda:3; workers per GPU: 1; total workers: 2; HanLP batch size: 32; overwrite: False
# Loading HanLP SRL on cuda:2 with model='https://file.hankcs.com/hanlp/mtl/en_tok_lem_pos_ner_srl_udep_sdp_con_modernbert_large_prepend_false_20250107_181612.zip'
# Loading HanLP SRL on cuda:3 with model='https://file.hankcs.com/hanlp/mtl/en_tok_lem_pos_ner_srl_udep_sdp_con_modernbert_large_prepend_false_20250107_181612.zip'
# Files:   0%|          | 0/1 [00:00<?, ?file/s]
# /home/volt/bach/python/Bython311/lib64/python3.11/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/volt/bach/python/Bython311/lib64/python3.11/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Building model ...Building model .../home/volt/bach/python/Bython311/lib64/python3.11/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/volt/bach/python/Bython311/lib64/python3.11/site-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Moving model to GPUs [3] ...
# Loading Stanza en on cuda:2 with package={'tokenize': 'ewt', 'pos': 'ewt', 'lemma': 'ewt'}, processors='tokenize,pos,lemma'
# 2026-08-28 16:02:52 WARNING: Language en package ewt expects mwt, which has been added
# 2026-08-28 16:02:52 INFO: Loading these models for language: en (English):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | ewt          |
# | mwt       | ewt          |
# | pos       | ewt_charlm   |
# | lemma     | ewt_nocharlm |
# ============================
#
# 2026-08-28 16:02:52 INFO: Using device: cuda:2
# 2026-08-28 16:02:52 INFO: Loading: tokenize
# 2026-08-28 16:02:52 INFO: Loading: mwt
# 2026-08-28 16:02:52 INFO: Loading: pos
# Loading Stanza en on cuda:3 with package={'tokenize': 'ewt', 'pos': 'ewt', 'lemma': 'ewt'}, processors='tokenize,pos,lemma'
# 2026-08-28 16:02:52 WARNING: Language en package ewt expects mwt, which has been added
# 2026-08-28 16:02:53 INFO: Loading these models for language: en (English):
# ============================
# | Processor | Package      |
# ----------------------------
# | tokenize  | ewt          |
# | mwt       | ewt          |
# | pos       | ewt_charlm   |
# | lemma     | ewt_nocharlm |
# ============================
#
# 2026-08-28 16:02:53 INFO: Using device: cuda:3
# 2026-08-28 16:02:53 INFO: Loading: tokenize
# 2026-08-28 16:02:53 INFO: Loading: mwt
# 2026-08-28 16:02:53 INFO: Loading: pos
# 2026-08-28 16:02:54 INFO: Loading: lemma
# 2026-08-28 16:02:54 INFO: Done loading processors!
# 2026-08-28 16:02:54 INFO: Loading: lemma
# 2026-08-28 16:02:54 INFO: Done loading processors!
# Files: 100%|██████████| 1/1 [00:50<00:00, 50.97s/file, parsed 300: 300_float_verb_sentences.txt]
# Done. Files: 1, skipped: 0, sentences parsed: 300
# PosixPath('/home/volt/bach/pilot_data/float_gen_srl')
